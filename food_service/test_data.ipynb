# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import statsmodels.api as sm

import warnings 
warnings.filterwarnings(action='ignore')

from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/SeoulHangangB.ttf"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
train = pd.read_csv('dataset/data/train.csv')

# %%
test = pd.read_csv('dataset/test_date.csv')

# %%
test.columns
# Out:
# Index(['일자', '요일', '본사정원수', '본사휴가자수', '본사출장자수', '본사시간외근무명령서승인건수',
#        '현본사소속재택근무자수', '조식메뉴', '중식메뉴', '석식메뉴', '년', '월', '일'],
#       dtype='object')

# %% [markdown]
# ## 식사가능자

# %%
test['식사가능자'] = test['본사정원수'] - test['본사휴가자수'] - test['본사출장자수'] - test['현본사소속재택근무자수']

# %% [markdown]
# ## 요일평균 식계

# %%
def make_dow_avg(df_test, df_prev):
    dow_avg_ln = df_prev.groupby('요일').mean()['중식계']
    dow_avg_dn = df_prev.groupby('요일').mean()['석식계']
    
    df_test['요일평균중식계'] = 0
    tmp = dow_avg_ln.values
    for i in range(len(tmp)):
        df_test['요일평균중식계'][df_test['요일'] == i] = tmp[i]
        
    df_test['요일평균석식계'] = 0
    tmp = dow_avg_dn.values
    for i in range(len(tmp)):
        df_test['요일평균석식계'][df_test['요일'] == i] = tmp[i]
    
    return df_test

# %% [markdown]
# ## 월평균식계

# %%
def make_month_avg(df_test, df_prev):
    month_avg_ln = df_prev.groupby('월').mean()['중식계']
    month_avg_dn = df_prev.groupby('월').mean()['석식계']
    
    df_test['월평균중식계'] = 0
    tmp = month_avg_ln
    tmp_k = tmp.keys(); tmp_v = tmp.values
    for i in tmp_k:
        df_test['월평균중식계'][df_test['월'] == i] = tmp_v[i-1]
        
    df_test['월평균석식계'] = 0
    tmp = month_avg_dn
    tmp_k = tmp.keys(); tmp_v = tmp.values
    for i in tmp_k:
        df_test['월평균석식계'][df_test['월'] == i] = tmp_v[i-1]
        
    return df_test

# %% [markdown]
# ## 공휴일전후

# %%
test['공휴일전후'] = 0
test['공휴일전후'][10] =1
test['공휴일전후'][20] = 1

# %% [markdown]
# # 모델

# %% [markdown]
# ## 점심

# %%
from pycaret.regression import *

# %%
train.columns
# Out:
# Index(['일자', '요일', '본사정원수', '본사휴가자수', '본사출장자수', '본사시간외근무명령서승인건수',
#        '현본사소속재택근무자수', '조식메뉴', '중식메뉴', '석식메뉴', '중식계', '석식계', '년', '월', '일',
#        '식사가능자', '전주중식계', '전주석식계', '요일평균중식계', '요일평균석식계', '월평균중식계', '월평균석식계',
#        '공휴일전후'],
#       dtype='object')

# %%
X_train_ln = train[['요일', '본사시간외근무명령서승인건수', '요일평균중식계', '월평균중식계', '공휴일전후',
                '본사휴가자수', '본사출장자수', '식사가능자', '중식계']]

# %%
reg = setup(session_id=1,
            data=X_train_ln,
            target='중식계',
            #numeric_imputation = 'mean',
            normalize = True,
            #categorical_features=['월', '요일', '공휴일전후'],
            silent=True)
# Out:
# <style  type="text/css" >
# #T_7faf7_row0_col1,#T_7faf7_row27_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_7faf7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7faf7_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7faf7_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_7faf7_row0_col1" class="data row0 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_7faf7_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7faf7_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_7faf7_row1_col1" class="data row1 col1" >중식계</td>
#             </tr>
#             <tr>
#                         <th id="T_7faf7_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_7faf7_row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_7faf7_row2_col1" class="data row2 col1" >(1205, 9)</td>
#             </tr>
#             <tr>
#                         <th id="T_7faf7_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_7faf7_row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_7faf7_row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_7faf7_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_7faf7_row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_7faf7_row4_col1" class="data row4 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_7faf7_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_7faf7_row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_7faf7_row5_col1" class="data row5 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_7faf7_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_7faf7_row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_7faf7_row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_7faf7_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_7faf7_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_7faf7_row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_7faf7_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_7faf7_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_7faf7_row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_7faf7_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_7faf7_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_7faf7_row9_col1" class="data row9 col1" >(843, 12)</td>
#             </tr>
#             <tr>
#                         <th id="T_7faf7_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_7faf7_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_7faf7_row10_col1" class="data row10 col1" >(362, 12)</td>
#             </tr>
#             <tr>
#                         <th id="T_7faf7_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_7faf7_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_7faf7_row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_7faf7_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_7faf7_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_7faf7_row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_7faf7_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_7faf7_row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_7faf7_row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_7faf7_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_7faf7_row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_7faf7_row14_col1" class="data row14 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_7faf7_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_7faf7_row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_7faf7_row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_7faf7_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_7faf7_row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_7faf7_row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_7faf7_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_7faf7_row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_7faf7_row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_7faf7_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_7faf7_row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_7faf7_row18_col1" class="data row18 col1" >reg-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_7faf7_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_7faf7_row19_col0" class="data row19 col0" >USI</td>
#                         <td id="T_7faf7_row19_col1" class="data row19 col1" >7c20</td>
#             </tr>
#             <tr>
#                         <th id="T_7faf7_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_7faf7_row20_col0" class="data row20 col0" >Imputation Type</td>
#                         <td id="T_7faf7_row20_col1" class="data row20 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_7faf7_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_7faf7_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_7faf7_row21_col1" class="data row21 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_7faf7_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_7faf7_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#                         <td id="T_7faf7_row22_col1" class="data row22 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_7faf7_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_7faf7_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#                         <td id="T_7faf7_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_7faf7_level0_row24" class="row_heading

# %%
top5 = compare_models(n_select=5, sort='MAE')
# Out:
# <style  type="text/css" >
#     #T_c50a7_ th {
#           text-align: left;
#     }#T_c50a7_row0_col0,#T_c50a7_row1_col0,#T_c50a7_row1_col1,#T_c50a7_row1_col2,#T_c50a7_row1_col3,#T_c50a7_row1_col4,#T_c50a7_row1_col5,#T_c50a7_row1_col6,#T_c50a7_row2_col0,#T_c50a7_row2_col1,#T_c50a7_row2_col2,#T_c50a7_row2_col3,#T_c50a7_row2_col4,#T_c50a7_row2_col5,#T_c50a7_row2_col6,#T_c50a7_row3_col0,#T_c50a7_row3_col1,#T_c50a7_row3_col2,#T_c50a7_row3_col3,#T_c50a7_row3_col4,#T_c50a7_row3_col5,#T_c50a7_row3_col6,#T_c50a7_row4_col0,#T_c50a7_row4_col1,#T_c50a7_row4_col2,#T_c50a7_row4_col3,#T_c50a7_row4_col4,#T_c50a7_row4_col5,#T_c50a7_row4_col6,#T_c50a7_row5_col0,#T_c50a7_row5_col1,#T_c50a7_row5_col2,#T_c50a7_row5_col3,#T_c50a7_row5_col4,#T_c50a7_row5_col5,#T_c50a7_row5_col6,#T_c50a7_row6_col0,#T_c50a7_row6_col1,#T_c50a7_row6_col2,#T_c50a7_row6_col3,#T_c50a7_row6_col4,#T_c50a7_row6_col5,#T_c50a7_row6_col6,#T_c50a7_row7_col0,#T_c50a7_row7_col1,#T_c50a7_row7_col2,#T_c50a7_row7_col3,#T_c50a7_row7_col4,#T_c50a7_row7_col5,#T_c50a7_row7_col6,#T_c50a7_row8_col0,#T_c50a7_row8_col1,#T_c50a7_row8_col2,#T_c50a7_row8_col3,#T_c50a7_row8_col4,#T_c50a7_row8_col5,#T_c50a7_row8_col6,#T_c50a7_row9_col0,#T_c50a7_row9_col1,#T_c50a7_row9_col2,#T_c50a7_row9_col3,#T_c50a7_row9_col4,#T_c50a7_row9_col5,#T_c50a7_row9_col6,#T_c50a7_row10_col0,#T_c50a7_row10_col1,#T_c50a7_row10_col2,#T_c50a7_row10_col3,#T_c50a7_row10_col4,#T_c50a7_row10_col5,#T_c50a7_row10_col6,#T_c50a7_row11_col0,#T_c50a7_row11_col1,#T_c50a7_row11_col2,#T_c50a7_row11_col3,#T_c50a7_row11_col4,#T_c50a7_row11_col5,#T_c50a7_row11_col6,#T_c50a7_row12_col0,#T_c50a7_row12_col1,#T_c50a7_row12_col2,#T_c50a7_row12_col3,#T_c50a7_row12_col4,#T_c50a7_row12_col5,#T_c50a7_row12_col6,#T_c50a7_row13_col0,#T_c50a7_row13_col1,#T_c50a7_row13_col2,#T_c50a7_row13_col3,#T_c50a7_row13_col4,#T_c50a7_row13_col5,#T_c50a7_row13_col6,#T_c50a7_row14_col0,#T_c50a7_row14_col1,#T_c50a7_row14_col2,#T_c50a7_row14_col3,#T_c50a7_row14_col4,#T_c50a7_row14_col5,#T_c50a7_row14_col6,#T_c50a7_row15_col0,#T_c50a7_row15_col1,#T_c50a7_row15_col2,#T_c50a7_row15_col3,#T_c50a7_row15_col4,#T_c50a7_row15_col5,#T_c50a7_row15_col6,#T_c50a7_row16_col0,#T_c50a7_row16_col1,#T_c50a7_row16_col2,#T_c50a7_row16_col3,#T_c50a7_row16_col4,#T_c50a7_row16_col5,#T_c50a7_row16_col6,#T_c50a7_row17_col0,#T_c50a7_row17_col1,#T_c50a7_row17_col2,#T_c50a7_row17_col3,#T_c50a7_row17_col4,#T_c50a7_row17_col5,#T_c50a7_row17_col6{
#             text-align:  left;
#             text-align:  left;
#         }#T_c50a7_row0_col1,#T_c50a7_row0_col2,#T_c50a7_row0_col3,#T_c50a7_row0_col4,#T_c50a7_row0_col5,#T_c50a7_row0_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_c50a7_row0_col7,#T_c50a7_row1_col7,#T_c50a7_row2_col7,#T_c50a7_row3_col7,#T_c50a7_row4_col7,#T_c50a7_row5_col7,#T_c50a7_row6_col7,#T_c50a7_row7_col7,#T_c50a7_row8_col7,#T_c50a7_row9_col7,#T_c50a7_row10_col7,#T_c50a7_row11_col7,#T_c50a7_row12_col7,#T_c50a7_row13_col7,#T_c50a7_row14_col7,#T_c50a7_row15_col7,#T_c50a7_row17_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_c50a7_row16_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_c50a7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>        <th class="col_heading level0 col7" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c50a7_level0_row0" class="row_heading level0 row0" >gbr</th>
#                         <td id="T_c50a7_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#                         <td id="T_c50a7_row0_col1" class="data row0 col1" >71.6987</td>
#                         <td id="T_c50a7_row0_col2" class="data row0 col2" >9188.7388</td>
#                         <td id="T_c50a7_row0_col3" class="data row0 col3" >94.9770</td>
#                         <td id="T_c50a7_row0_col4" class="data row0 col4" >0.7870</td>
#                         <td id="T_c50a7_row0_col5" class="data row0 col5" >0.1166</td>
#                         <td id="T_c50a7_row0_col6" class="data row0 col6" >0.0865</td>
#                         <td id="T_c50a7_row0_col7" class="data row0 col7" >0.0190</td>
#             </tr>
#             <tr>
#                         <th id="T_c50a7_level0_row1" class="row_heading level0 row1" >rf</th>
#                         <td id="T_c50a7_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#                         <td id="T_c50a7_row1_col1" class="data row1 col1" >74.7794</td>
#                         <td id="T_c50a7_row1_col2" class="data row1 col2" >9933.5249</td>
#                         <td id="T_c50a7_row1_col3" class="data row1 col3" >98.8920</td>
#                         <td id="T_c50a7_row1_col4" class="data row1 col4" >0.7704</td>
#                         <td id="T_c50a7_row1_col5" class="data row1 col5" >0.1226</td>
#                         <td id="T_c50a7_row1_col6" class="data row1 col6" >0.0908</td>
#                         <td id="T_c50a7_row1_col7" class="data row1 col7" >0.0570</td>
#             </tr>
#             <tr>
#                         <th id="T_c50a7_level0_row2" class="row_heading level0 row2" >et</th>
#                         <td id="T_c50a7_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#                         <td id="T_c50a7_row2_col1" class="data row2 col1" >75.5542</td>
#                         <td id="T_c50a7_row2_col2" class="data row2 col2" >10330.2492</td>
#                         <td id="T_c50a7_row2_col3" class="data row2 col3" >100.8986</td>
#                         <td id="T_c50a7_row2_col4" class="data row2 col4" >0.7621</td>
#                         <td id="T_c50a7_row2_col5" class="data row2 col5" >0.1261</td>
#                         <td id="T_c50a7_row2_col6" class="data row2 col6" >0.0924</td>
#                         <td id="T_c50a7_row2_col7" class="data row2 col7" >0.0540</td>
#             </tr>
#             <tr>
#                         <th id="T_c50a7_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#                         <td id="T_c50a7_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_c50a7_row3_col1" class="data row3 col1" >76.0612</td>
#                         <td id="T_c50a7_row3_col2" class="data row3 col2" >10114.2297</td>
#                         <td id="T_c50a7_row3_col3" class="data row3 col3" >100.0402</td>
#                         <td id="T_c50a7_row3_col4" class="data row3 col4" >0.7650</td>
#                         <td id="T_c50a7_row3_col5" class="data row3 col5" >0.1241</td>
#                         <td id="T_c50a7_row3_col6" class="data row3 col6" >0.0919</td>
#                         <td id="T_c50a7_row3_col7" class="data row3 col7" >0.0380</td>
#             </tr>
#             <tr>
#                         <th id="T_c50a7_level0_row4" class="row_heading level0 row4" >huber</th>
#                         <td id="T_c50a7_row4_col0" class="data row4 col0" >Huber Regressor</td>
#                         <td id="T_c50a7_row4_col1" class="data row4 col1" >76.8121</td>
#                         <td id="T_c50a7_row4_col2" class="data row4 col2" >10528.1556</td>
#                         <td id="T_c50a7_row4_col3" class="data row4 col3" >101.7810</td>
#                         <td id="T_c50a7_row4_col4" class="data row4 col4" >0.7558</td>
#                         <td id="T_c50a7_row4_col5" class="data row4 col5" >0.1290</td>
#                         <td id="T_c50a7_row4_col6" class="data r

# %%
gbr_l = tune_model(create_model('gbr', criterion='mae'), optimize='MAE')
# Out:
# <style  type="text/css" >
# #T_55fbb_row10_col0,#T_55fbb_row10_col1,#T_55fbb_row10_col2,#T_55fbb_row10_col3,#T_55fbb_row10_col4,#T_55fbb_row10_col5{
#             background:  yellow;
#         }</style><table id="T_55fbb_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_55fbb_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_55fbb_row0_col0" class="data row0 col0" >88.2727</td>
#                         <td id="T_55fbb_row0_col1" class="data row0 col1" >13746.7424</td>
#                         <td id="T_55fbb_row0_col2" class="data row0 col2" >117.2465</td>
#                         <td id="T_55fbb_row0_col3" class="data row0 col3" >0.7228</td>
#                         <td id="T_55fbb_row0_col4" class="data row0 col4" >0.1524</td>
#                         <td id="T_55fbb_row0_col5" class="data row0 col5" >0.1099</td>
#             </tr>
#             <tr>
#                         <th id="T_55fbb_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_55fbb_row1_col0" class="data row1 col0" >82.7647</td>
#                         <td id="T_55fbb_row1_col1" class="data row1 col1" >12924.7530</td>
#                         <td id="T_55fbb_row1_col2" class="data row1 col2" >113.6871</td>
#                         <td id="T_55fbb_row1_col3" class="data row1 col3" >0.6256</td>
#                         <td id="T_55fbb_row1_col4" class="data row1 col4" >0.1237</td>
#                         <td id="T_55fbb_row1_col5" class="data row1 col5" >0.0907</td>
#             </tr>
#             <tr>
#                         <th id="T_55fbb_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_55fbb_row2_col0" class="data row2 col0" >66.3824</td>
#                         <td id="T_55fbb_row2_col1" class="data row2 col1" >7994.5610</td>
#                         <td id="T_55fbb_row2_col2" class="data row2 col2" >89.4123</td>
#                         <td id="T_55fbb_row2_col3" class="data row2 col3" >0.8100</td>
#                         <td id="T_55fbb_row2_col4" class="data row2 col4" >0.1121</td>
#                         <td id="T_55fbb_row2_col5" class="data row2 col5" >0.0826</td>
#             </tr>
#             <tr>
#                         <th id="T_55fbb_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_55fbb_row3_col0" class="data row3 col0" >62.3398</td>
#                         <td id="T_55fbb_row3_col1" class="data row3 col1" >7374.8927</td>
#                         <td id="T_55fbb_row3_col2" class="data row3 col2" >85.8772</td>
#                         <td id="T_55fbb_row3_col3" class="data row3 col3" >0.8439</td>
#                         <td id="T_55fbb_row3_col4" class="data row3 col4" >0.1218</td>
#                         <td id="T_55fbb_row3_col5" class="data row3 col5" >0.0856</td>
#             </tr>
#             <tr>
#                         <th id="T_55fbb_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_55fbb_row4_col0" class="data row4 col0" >59.5834</td>
#                         <td id="T_55fbb_row4_col1" class="data row4 col1" >5892.5583</td>
#                         <td id="T_55fbb_row4_col2" class="data row4 col2" >76.7630</td>
#                         <td id="T_55fbb_row4_col3" class="data row4 col3" >0.8507</td>
#                         <td id="T_55fbb_row4_col4" class="data row4 col4" >0.0885</td>
#                         <td id="T_55fbb_row4_col5" class="data row4 col5" >0.0673</td>
#             </tr>
#             <tr>
#                         <th id="T_55fbb_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_55fbb_row5_col0" class="data row5 col0" >69.2123</td>
#                         <td id="T_55fbb_row5_col1" class="data row5 col1" >9104.5558</td>
#                         <td id="T_55fbb_row5_col2" class="data row5 col2" >95.4178</td>
#                         <td id="T_55fbb_row5_col3" class="data row5 col3" >0.7986</td>
#                         <td id="T_55fbb_row5_col4" class="data row5 col4" >0.1243</td>
#                         <td id="T_55fbb_row5_col5" class="data row5 col5" >0.0858</td>
#             </tr>
#             <tr>
#                         <th id="T_55fbb_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_55fbb_row6_col0" class="data row6 col0" >75.4561</td>
#                         <td id="T_55fbb_row6_col1" class="data row6 col1" >11448.2869</td>
#                         <td id="T_55fbb_row6_col2" class="data row6 col2" >106.9967</td>
#                         <td id="T_55fbb_row6_col3" class="data row6 col3" >0.7419</td>
#                         <td id="T_55fbb_row6_col4" class="data row6 col4" >0.1211</td>
#                         <td id="T_55fbb_row6_col5" class="data row6 col5" >0.0869</td>
#             </tr>
#             <tr>
#                         <th id="T_55fbb_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_55fbb_row7_col0" class="data row7 col0" >71.9898</td>
#                         <td id="T_55fbb_row7_col1" class="data row7 col1" >7911.8279</td>
#                         <td id="T_55fbb_row7_col2" class="data row7 col2" >88.9485</td>
#                         <td id="T_55fbb_row7_col3" class="data row7 col3" >0.7586</td>
#                         <td id="T_55fbb_row7_col4" class="data row7 col4" >0.1041</td>
#                         <td id="T_55fbb_row7_col5" class="data row7 col5" >0.0832</td>
#             </tr>
#             <tr>
#                         <th id="T_55fbb_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_55fbb_row8_col0" class="data row8 col0" >70.9892</td>
#                         <td id="T_55fbb_row8_col1" class="data row8 col1" >8850.8715</td>
#                         <td id="T_55fbb_row8_col2" class="data row8 col2" >94.0791</td>
#                         <td id="T_55fbb_row8_col3" class="data row8 col3" >0.8182</td>
#                         <td id="T_55fbb_row8_col4" class="data row8 col4" >0.1081</td>
#                         <td id="T_55fbb_row8_col5" class="data row8 col5" >0.0836</td>
#             </tr>
#             <tr>
#                         <th id="T_55fbb_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_55fbb_row9_col0" class="data row9 col0" >70.2892</td>
#                         <td id="T_55fbb_row9_col1" class="data row9 col1" >9311.9494</td>
#                         <td id="T_55fbb_row9_col2" class="data row9 col2" >96.4984</td>
#                         <td id="T_55fbb_row9_col3" class="data row9 col3" >0.8278</td>
#                         <td id="T_55fbb_row9_col4" class="data row9 col4" >0.1409</td>
#                         <td id="T_55fbb_row9_col5" class="data row9 col5" >0.0952</td>
#             </tr>
#             <tr>
#                         <th id="T_55fbb_level0_row10" class="row_heading level0 row10" >Mean</th>
#                         <td id="T_55fbb_row10_col0" class="data row10 col0" >71.7280</td>
#                         <td id="T_55fbb_row10_col1" class="data row10 col1" >9456.0999</td>
#                         <td id="T_55fbb_row10_col2" class="data row10 col2" >96.4927</td>
#                         <td id="T_55fbb_row10_col3" class="data row10 col3" >0.7798</td>
#                         <td id="T_55fbb_row10_col4" class="data row10 col4" >0.1197</td>
#                         <td id="T_55fbb_row10_col5" class="data row10 col5" >0.0871</td>
#             </tr>
#             <tr>
#                         <th id="T_55fbb_level0_row11" class="row_heading level0 row11" >SD</th>
#                         <td id="T_55

# %%
pred_holdouts = predict_model(gbr_l)
final_model_l = finalize_model(gbr_l)
final_model_l
# Out:
# <style  type="text/css" >
# </style><table id="T_16743_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_16743_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_16743_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#                         <td id="T_16743_row0_col1" class="data row0 col1" >70.9156</td>
#                         <td id="T_16743_row0_col2" class="data row0 col2" >9193.5047</td>
#                         <td id="T_16743_row0_col3" class="data row0 col3" >95.8828</td>
#                         <td id="T_16743_row0_col4" class="data row0 col4" >0.7873</td>
#                         <td id="T_16743_row0_col5" class="data row0 col5" >0.1200</td>
#                         <td id="T_16743_row0_col6" class="data row0 col6" >0.0884</td>
#             </tr>
#     </tbody></table>
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='mae', init=None,
#                           learning_rate=0.05, loss='ls', max_depth=4,
#                           max_features='sqrt', max_leaf_nodes=None,
#                           min_impurity_decrease=0.05, min_impurity_split=None,
#                           min_samples_leaf=2, min_samples_split=4,
#                           min_weight_fraction_leaf=0.0, n_estimators=260,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=1, subsample=0.8, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %% [markdown]
# ## 저녁

# %%
X_train_dn = train[['요일', '본사시간외근무명령서승인건수', '공휴일전후', '요일평균석식계', '월평균석식계', '본사출장자수',
                 '식사가능자', '월', '일', '석식계']]

# %%
reg = setup(session_id=2,
            data=X_train_dn,
            target='석식계',
            #numeric_imputation = 'mean',
            normalize = True,
            #categorical_features=['월', '요일', '공휴일전후'],
            silent=True)
# Out:
# <style  type="text/css" >
# #T_f10da_row27_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_f10da_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f10da_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f10da_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_f10da_row0_col1" class="data row0 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_f10da_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f10da_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_f10da_row1_col1" class="data row1 col1" >석식계</td>
#             </tr>
#             <tr>
#                         <th id="T_f10da_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f10da_row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_f10da_row2_col1" class="data row2 col1" >(1205, 10)</td>
#             </tr>
#             <tr>
#                         <th id="T_f10da_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f10da_row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_f10da_row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f10da_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f10da_row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_f10da_row4_col1" class="data row4 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_f10da_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f10da_row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_f10da_row5_col1" class="data row5 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_f10da_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_f10da_row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_f10da_row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f10da_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_f10da_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_f10da_row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f10da_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_f10da_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_f10da_row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_f10da_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_f10da_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_f10da_row9_col1" class="data row9 col1" >(843, 24)</td>
#             </tr>
#             <tr>
#                         <th id="T_f10da_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_f10da_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_f10da_row10_col1" class="data row10 col1" >(362, 24)</td>
#             </tr>
#             <tr>
#                         <th id="T_f10da_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_f10da_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_f10da_row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_f10da_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_f10da_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_f10da_row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f10da_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_f10da_row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_f10da_row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_f10da_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_f10da_row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_f10da_row14_col1" class="data row14 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_f10da_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_f10da_row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_f10da_row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_f10da_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_f10da_row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_f10da_row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f10da_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_f10da_row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_f10da_row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f10da_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_f10da_row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_f10da_row18_col1" class="data row18 col1" >reg-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_f10da_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_f10da_row19_col0" class="data row19 col0" >USI</td>
#                         <td id="T_f10da_row19_col1" class="data row19 col1" >9d81</td>
#             </tr>
#             <tr>
#                         <th id="T_f10da_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_f10da_row20_col0" class="data row20 col0" >Imputation Type</td>
#                         <td id="T_f10da_row20_col1" class="data row20 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_f10da_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_f10da_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_f10da_row21_col1" class="data row21 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_f10da_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_f10da_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#                         <td id="T_f10da_row22_col1" class="data row22 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_f10da_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_f10da_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#                         <td id="T_f10da_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_f10da_level0_row24" class="row_heading level0 row24" >24<

# %%
top5 = compare_models(n_select=5, sort='MAE')
# Out:
# <style  type="text/css" >
#     #T_6f9d2_ th {
#           text-align: left;
#     }#T_6f9d2_row0_col0,#T_6f9d2_row0_col2,#T_6f9d2_row0_col3,#T_6f9d2_row0_col5,#T_6f9d2_row0_col6,#T_6f9d2_row1_col0,#T_6f9d2_row1_col1,#T_6f9d2_row1_col2,#T_6f9d2_row1_col3,#T_6f9d2_row1_col4,#T_6f9d2_row1_col5,#T_6f9d2_row2_col0,#T_6f9d2_row2_col1,#T_6f9d2_row2_col4,#T_6f9d2_row2_col5,#T_6f9d2_row2_col6,#T_6f9d2_row3_col0,#T_6f9d2_row3_col1,#T_6f9d2_row3_col2,#T_6f9d2_row3_col3,#T_6f9d2_row3_col4,#T_6f9d2_row3_col5,#T_6f9d2_row3_col6,#T_6f9d2_row4_col0,#T_6f9d2_row4_col1,#T_6f9d2_row4_col2,#T_6f9d2_row4_col3,#T_6f9d2_row4_col4,#T_6f9d2_row4_col6,#T_6f9d2_row5_col0,#T_6f9d2_row5_col1,#T_6f9d2_row5_col2,#T_6f9d2_row5_col3,#T_6f9d2_row5_col4,#T_6f9d2_row5_col5,#T_6f9d2_row5_col6,#T_6f9d2_row6_col0,#T_6f9d2_row6_col1,#T_6f9d2_row6_col2,#T_6f9d2_row6_col3,#T_6f9d2_row6_col4,#T_6f9d2_row6_col5,#T_6f9d2_row6_col6,#T_6f9d2_row7_col0,#T_6f9d2_row7_col1,#T_6f9d2_row7_col2,#T_6f9d2_row7_col3,#T_6f9d2_row7_col4,#T_6f9d2_row7_col5,#T_6f9d2_row7_col6,#T_6f9d2_row8_col0,#T_6f9d2_row8_col1,#T_6f9d2_row8_col2,#T_6f9d2_row8_col3,#T_6f9d2_row8_col4,#T_6f9d2_row8_col5,#T_6f9d2_row8_col6,#T_6f9d2_row9_col0,#T_6f9d2_row9_col1,#T_6f9d2_row9_col2,#T_6f9d2_row9_col3,#T_6f9d2_row9_col4,#T_6f9d2_row9_col5,#T_6f9d2_row9_col6,#T_6f9d2_row10_col0,#T_6f9d2_row10_col1,#T_6f9d2_row10_col2,#T_6f9d2_row10_col3,#T_6f9d2_row10_col4,#T_6f9d2_row10_col5,#T_6f9d2_row10_col6,#T_6f9d2_row11_col0,#T_6f9d2_row11_col1,#T_6f9d2_row11_col2,#T_6f9d2_row11_col3,#T_6f9d2_row11_col4,#T_6f9d2_row11_col5,#T_6f9d2_row11_col6,#T_6f9d2_row12_col0,#T_6f9d2_row12_col1,#T_6f9d2_row12_col2,#T_6f9d2_row12_col3,#T_6f9d2_row12_col4,#T_6f9d2_row12_col5,#T_6f9d2_row12_col6,#T_6f9d2_row13_col0,#T_6f9d2_row13_col1,#T_6f9d2_row13_col2,#T_6f9d2_row13_col3,#T_6f9d2_row13_col4,#T_6f9d2_row13_col5,#T_6f9d2_row13_col6,#T_6f9d2_row14_col0,#T_6f9d2_row14_col1,#T_6f9d2_row14_col2,#T_6f9d2_row14_col3,#T_6f9d2_row14_col4,#T_6f9d2_row14_col5,#T_6f9d2_row14_col6,#T_6f9d2_row15_col0,#T_6f9d2_row15_col1,#T_6f9d2_row15_col2,#T_6f9d2_row15_col3,#T_6f9d2_row15_col4,#T_6f9d2_row15_col5,#T_6f9d2_row15_col6,#T_6f9d2_row16_col0,#T_6f9d2_row16_col1,#T_6f9d2_row16_col2,#T_6f9d2_row16_col3,#T_6f9d2_row16_col4,#T_6f9d2_row16_col5,#T_6f9d2_row16_col6,#T_6f9d2_row17_col0,#T_6f9d2_row17_col1,#T_6f9d2_row17_col2,#T_6f9d2_row17_col3,#T_6f9d2_row17_col4,#T_6f9d2_row17_col5,#T_6f9d2_row17_col6{
#             text-align:  left;
#             text-align:  left;
#         }#T_6f9d2_row0_col1,#T_6f9d2_row0_col4,#T_6f9d2_row1_col6,#T_6f9d2_row2_col2,#T_6f9d2_row2_col3,#T_6f9d2_row4_col5{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_6f9d2_row0_col7,#T_6f9d2_row1_col7,#T_6f9d2_row2_col7,#T_6f9d2_row3_col7,#T_6f9d2_row4_col7,#T_6f9d2_row5_col7,#T_6f9d2_row6_col7,#T_6f9d2_row7_col7,#T_6f9d2_row8_col7,#T_6f9d2_row9_col7,#T_6f9d2_row11_col7,#T_6f9d2_row13_col7,#T_6f9d2_row16_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_6f9d2_row10_col7,#T_6f9d2_row12_col7,#T_6f9d2_row14_col7,#T_6f9d2_row15_col7,#T_6f9d2_row17_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_6f9d2_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>        <th class="col_heading level0 col7" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6f9d2_level0_row0" class="row_heading level0 row0" >rf</th>
#                         <td id="T_6f9d2_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#                         <td id="T_6f9d2_row0_col1" class="data row0 col1" >60.2581</td>
#                         <td id="T_6f9d2_row0_col2" class="data row0 col2" >7575.4456</td>
#                         <td id="T_6f9d2_row0_col3" class="data row0 col3" >86.6464</td>
#                         <td id="T_6f9d2_row0_col4" class="data row0 col4" >0.5937</td>
#                         <td id="T_6f9d2_row0_col5" class="data row0 col5" >0.8682</td>
#                         <td id="T_6f9d2_row0_col6" class="data row0 col6" >0.1331</td>
#                         <td id="T_6f9d2_row0_col7" class="data row0 col7" >0.0630</td>
#             </tr>
#             <tr>
#                         <th id="T_6f9d2_level0_row1" class="row_heading level0 row1" >et</th>
#                         <td id="T_6f9d2_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#                         <td id="T_6f9d2_row1_col1" class="data row1 col1" >61.8387</td>
#                         <td id="T_6f9d2_row1_col2" class="data row1 col2" >8157.4263</td>
#                         <td id="T_6f9d2_row1_col3" class="data row1 col3" >89.7794</td>
#                         <td id="T_6f9d2_row1_col4" class="data row1 col4" >0.5451</td>
#                         <td id="T_6f9d2_row1_col5" class="data row1 col5" >0.8934</td>
#                         <td id="T_6f9d2_row1_col6" class="data row1 col6" >0.1328</td>
#                         <td id="T_6f9d2_row1_col7" class="data row1 col7" >0.0550</td>
#             </tr>
#             <tr>
#                         <th id="T_6f9d2_level0_row2" class="row_heading level0 row2" >gbr</th>
#                         <td id="T_6f9d2_row2_col0" class="data row2 col0" >Gradient Boosting Regressor</td>
#                         <td id="T_6f9d2_row2_col1" class="data row2 col1" >62.4500</td>
#                         <td id="T_6f9d2_row2_col2" class="data row2 col2" >7491.1622</td>
#                         <td id="T_6f9d2_row2_col3" class="data row2 col3" >86.2427</td>
#                         <td id="T_6f9d2_row2_col4" class="data row2 col4" >0.5931</td>
#                         <td id="T_6f9d2_row2_col5" class="data row2 col5" >0.9307</td>
#                         <td id="T_6f9d2_row2_col6" class="data row2 col6" >0.1344</td>
#                         <td id="T_6f9d2_row2_col7" class="data row2 col7" >0.0200</td>
#             </tr>
#             <tr>
#                         <th id="T_6f9d2_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#                         <td id="T_6f9d2_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_6f9d2_row3_col1" class="data row3 col1" >63.6084</td>
#                         <td id="T_6f9d2_row3_col2" class="data row3 col2" >7791.5239</td>
#                         <td id="T_6f9d2_row3_col3" class="data row3 col3" >87.9003</td>
#                         <td id="T_6f9d2_row3_col4" class="data row3 col4" >0.5776</td>
#                         <td id="T_6f9d2_row3_col5" class="data row3 col5" >0.8972</td>
#                         <td id="T_6f9d2_row3_col6" class="data row3 col6" >0.1410</td>
#                         <td id="T_6f9d2_row3_col7" class="data row3 col7" >0.0560</td>
#             </tr>
#             <tr>
#                         <th id="T_6f9d2_level0_row4" class="row_heading level0 row4" >xgboost</th>
#                         <td id="T_6f9d2_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#                         <td id="T_6f9d2_row4_col1" class="data row4 col1" >64.6017</td>
#                         <td id="T_6f9d2_row4_col2" class="data row4 col2" >7860.4843</td>
#                         <td id="T_6f9d2_row4_col3" class="data row4 col3" >88.4012</td>
#                         <td id="T_6f9d2_row4_col4" class="data row4 col4" >0.5604</td>
#                         <td id="T_6f9d2_row4_col5" class="data row4 col5" >0.8426</td>
#                         <td id="T_6f9d2_row4_col6" class="

# %%
blended_d = blend_models(top5, optimize='MAE')
# Out:
# <style  type="text/css" >
# #T_4d75a_row10_col0,#T_4d75a_row10_col1,#T_4d75a_row10_col2,#T_4d75a_row10_col3,#T_4d75a_row10_col4,#T_4d75a_row10_col5{
#             background:  yellow;
#         }</style><table id="T_4d75a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4d75a_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4d75a_row0_col0" class="data row0 col0" >62.0521</td>
#                         <td id="T_4d75a_row0_col1" class="data row0 col1" >10125.1279</td>
#                         <td id="T_4d75a_row0_col2" class="data row0 col2" >100.6237</td>
#                         <td id="T_4d75a_row0_col3" class="data row0 col3" >0.5428</td>
#                         <td id="T_4d75a_row0_col4" class="data row0 col4" >1.1448</td>
#                         <td id="T_4d75a_row0_col5" class="data row0 col5" >0.1437</td>
#             </tr>
#             <tr>
#                         <th id="T_4d75a_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4d75a_row1_col0" class="data row1 col0" >61.8531</td>
#                         <td id="T_4d75a_row1_col1" class="data row1 col1" >7278.2191</td>
#                         <td id="T_4d75a_row1_col2" class="data row1 col2" >85.3125</td>
#                         <td id="T_4d75a_row1_col3" class="data row1 col3" >0.3254</td>
#                         <td id="T_4d75a_row1_col4" class="data row1 col4" >0.2000</td>
#                         <td id="T_4d75a_row1_col5" class="data row1 col5" >0.1416</td>
#             </tr>
#             <tr>
#                         <th id="T_4d75a_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4d75a_row2_col0" class="data row2 col0" >61.1631</td>
#                         <td id="T_4d75a_row2_col1" class="data row2 col1" >7160.0302</td>
#                         <td id="T_4d75a_row2_col2" class="data row2 col2" >84.6170</td>
#                         <td id="T_4d75a_row2_col3" class="data row2 col3" >0.6366</td>
#                         <td id="T_4d75a_row2_col4" class="data row2 col4" >0.9858</td>
#                         <td id="T_4d75a_row2_col5" class="data row2 col5" >0.1173</td>
#             </tr>
#             <tr>
#                         <th id="T_4d75a_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4d75a_row3_col0" class="data row3 col0" >59.8715</td>
#                         <td id="T_4d75a_row3_col1" class="data row3 col1" >6268.7608</td>
#                         <td id="T_4d75a_row3_col2" class="data row3 col2" >79.1755</td>
#                         <td id="T_4d75a_row3_col3" class="data row3 col3" >0.6039</td>
#                         <td id="T_4d75a_row3_col4" class="data row3 col4" >0.6031</td>
#                         <td id="T_4d75a_row3_col5" class="data row3 col5" >0.1358</td>
#             </tr>
#             <tr>
#                         <th id="T_4d75a_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4d75a_row4_col0" class="data row4 col0" >57.4162</td>
#                         <td id="T_4d75a_row4_col1" class="data row4 col1" >6987.4238</td>
#                         <td id="T_4d75a_row4_col2" class="data row4 col2" >83.5908</td>
#                         <td id="T_4d75a_row4_col3" class="data row4 col3" >0.6127</td>
#                         <td id="T_4d75a_row4_col4" class="data row4 col4" >0.8597</td>
#                         <td id="T_4d75a_row4_col5" class="data row4 col5" >0.1259</td>
#             </tr>
#             <tr>
#                         <th id="T_4d75a_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4d75a_row5_col0" class="data row5 col0" >53.9196</td>
#                         <td id="T_4d75a_row5_col1" class="data row5 col1" >5262.1323</td>
#                         <td id="T_4d75a_row5_col2" class="data row5 col2" >72.5406</td>
#                         <td id="T_4d75a_row5_col3" class="data row5 col3" >0.6534</td>
#                         <td id="T_4d75a_row5_col4" class="data row5 col4" >0.7390</td>
#                         <td id="T_4d75a_row5_col5" class="data row5 col5" >0.1139</td>
#             </tr>
#             <tr>
#                         <th id="T_4d75a_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_4d75a_row6_col0" class="data row6 col0" >59.4558</td>
#                         <td id="T_4d75a_row6_col1" class="data row6 col1" >5703.5676</td>
#                         <td id="T_4d75a_row6_col2" class="data row6 col2" >75.5220</td>
#                         <td id="T_4d75a_row6_col3" class="data row6 col3" >0.7506</td>
#                         <td id="T_4d75a_row6_col4" class="data row6 col4" >1.0034</td>
#                         <td id="T_4d75a_row6_col5" class="data row6 col5" >0.1350</td>
#             </tr>
#             <tr>
#                         <th id="T_4d75a_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_4d75a_row7_col0" class="data row7 col0" >59.4769</td>
#                         <td id="T_4d75a_row7_col1" class="data row7 col1" >6094.9212</td>
#                         <td id="T_4d75a_row7_col2" class="data row7 col2" >78.0700</td>
#                         <td id="T_4d75a_row7_col3" class="data row7 col3" >0.6836</td>
#                         <td id="T_4d75a_row7_col4" class="data row7 col4" >0.9458</td>
#                         <td id="T_4d75a_row7_col5" class="data row7 col5" >0.1314</td>
#             </tr>
#             <tr>
#                         <th id="T_4d75a_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_4d75a_row8_col0" class="data row8 col0" >63.7731</td>
#                         <td id="T_4d75a_row8_col1" class="data row8 col1" >7589.0372</td>
#                         <td id="T_4d75a_row8_col2" class="data row8 col2" >87.1151</td>
#                         <td id="T_4d75a_row8_col3" class="data row8 col3" >0.6371</td>
#                         <td id="T_4d75a_row8_col4" class="data row8 col4" >0.9104</td>
#                         <td id="T_4d75a_row8_col5" class="data row8 col5" >0.1506</td>
#             </tr>
#             <tr>
#                         <th id="T_4d75a_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_4d75a_row9_col0" class="data row9 col0" >59.1525</td>
#                         <td id="T_4d75a_row9_col1" class="data row9 col1" >8111.9828</td>
#                         <td id="T_4d75a_row9_col2" class="data row9 col2" >90.0665</td>
#                         <td id="T_4d75a_row9_col3" class="data row9 col3" >0.6921</td>
#                         <td id="T_4d75a_row9_col4" class="data row9 col4" >1.5458</td>
#                         <td id="T_4d75a_row9_col5" class="data row9 col5" >0.1067</td>
#             </tr>
#             <tr>
#                         <th id="T_4d75a_level0_row10" class="row_heading level0 row10" >Mean</th>
#                         <td id="T_4d75a_row10_col0" class="data row10 col0" >59.8134</td>
#                         <td id="T_4d75a_row10_col1" class="data row10 col1" >7058.1203</td>
#                         <td id="T_4d75a_row10_col2" class="data row10 col2" >83.6634</td>
#                         <td id="T_4d75a_row10_col3" class="data row10 col3" >0.6138</td>
#                         <td id="T_4d75a_row10_col4" class="data row10 col4" >0.8938</td>
#                         <td id="T_4d75a_row10_col5" class="data row10 col5" >0.1302</td>
#             </tr>
#             <tr>
#                         <th id="T_4d75a_level0_row11" class="row_heading level0 row11" >SD</th>
#                         <td id="T_4d75a_

# %%
params = {'learning_rate': [0.0, 0.1, 0.09, 0.089, 0.08],
                  'booster': ['gbtree', 'gblinear', 'dart']}
xgb_ = tune_model(create_model('xgboost', gpu_id=0), optimize='MAE', custom_grid=params)
# Out:
# <style  type="text/css" >
# #T_0a2ef_row10_col0,#T_0a2ef_row10_col1,#T_0a2ef_row10_col2,#T_0a2ef_row10_col3,#T_0a2ef_row10_col4,#T_0a2ef_row10_col5{
#             background:  yellow;
#         }</style><table id="T_0a2ef_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0a2ef_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0a2ef_row0_col0" class="data row0 col0" >62.1833</td>
#                         <td id="T_0a2ef_row0_col1" class="data row0 col1" >9369.4248</td>
#                         <td id="T_0a2ef_row0_col2" class="data row0 col2" >96.7958</td>
#                         <td id="T_0a2ef_row0_col3" class="data row0 col3" >0.5769</td>
#                         <td id="T_0a2ef_row0_col4" class="data row0 col4" >1.1035</td>
#                         <td id="T_0a2ef_row0_col5" class="data row0 col5" >0.1450</td>
#             </tr>
#             <tr>
#                         <th id="T_0a2ef_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_0a2ef_row1_col0" class="data row1 col0" >60.3312</td>
#                         <td id="T_0a2ef_row1_col1" class="data row1 col1" >7256.3042</td>
#                         <td id="T_0a2ef_row1_col2" class="data row1 col2" >85.1839</td>
#                         <td id="T_0a2ef_row1_col3" class="data row1 col3" >0.3274</td>
#                         <td id="T_0a2ef_row1_col4" class="data row1 col4" >0.2052</td>
#                         <td id="T_0a2ef_row1_col5" class="data row1 col5" >0.1370</td>
#             </tr>
#             <tr>
#                         <th id="T_0a2ef_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_0a2ef_row2_col0" class="data row2 col0" >62.1439</td>
#                         <td id="T_0a2ef_row2_col1" class="data row2 col1" >7583.8779</td>
#                         <td id="T_0a2ef_row2_col2" class="data row2 col2" >87.0855</td>
#                         <td id="T_0a2ef_row2_col3" class="data row2 col3" >0.6151</td>
#                         <td id="T_0a2ef_row2_col4" class="data row2 col4" >0.9347</td>
#                         <td id="T_0a2ef_row2_col5" class="data row2 col5" >0.1231</td>
#             </tr>
#             <tr>
#                         <th id="T_0a2ef_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_0a2ef_row3_col0" class="data row3 col0" >56.7220</td>
#                         <td id="T_0a2ef_row3_col1" class="data row3 col1" >6179.6353</td>
#                         <td id="T_0a2ef_row3_col2" class="data row3 col2" >78.6107</td>
#                         <td id="T_0a2ef_row3_col3" class="data row3 col3" >0.6096</td>
#                         <td id="T_0a2ef_row3_col4" class="data row3 col4" >0.6057</td>
#                         <td id="T_0a2ef_row3_col5" class="data row3 col5" >0.1292</td>
#             </tr>
#             <tr>
#                         <th id="T_0a2ef_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_0a2ef_row4_col0" class="data row4 col0" >56.5045</td>
#                         <td id="T_0a2ef_row4_col1" class="data row4 col1" >6577.9307</td>
#                         <td id="T_0a2ef_row4_col2" class="data row4 col2" >81.1044</td>
#                         <td id="T_0a2ef_row4_col3" class="data row4 col3" >0.6354</td>
#                         <td id="T_0a2ef_row4_col4" class="data row4 col4" >0.7815</td>
#                         <td id="T_0a2ef_row4_col5" class="data row4 col5" >0.1258</td>
#             </tr>
#             <tr>
#                         <th id="T_0a2ef_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_0a2ef_row5_col0" class="data row5 col0" >55.5339</td>
#                         <td id="T_0a2ef_row5_col1" class="data row5 col1" >5508.5537</td>
#                         <td id="T_0a2ef_row5_col2" class="data row5 col2" >74.2196</td>
#                         <td id="T_0a2ef_row5_col3" class="data row5 col3" >0.6371</td>
#                         <td id="T_0a2ef_row5_col4" class="data row5 col4" >0.6679</td>
#                         <td id="T_0a2ef_row5_col5" class="data row5 col5" >0.1189</td>
#             </tr>
#             <tr>
#                         <th id="T_0a2ef_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_0a2ef_row6_col0" class="data row6 col0" >56.1677</td>
#                         <td id="T_0a2ef_row6_col1" class="data row6 col1" >5366.3232</td>
#                         <td id="T_0a2ef_row6_col2" class="data row6 col2" >73.2552</td>
#                         <td id="T_0a2ef_row6_col3" class="data row6 col3" >0.7653</td>
#                         <td id="T_0a2ef_row6_col4" class="data row6 col4" >0.8908</td>
#                         <td id="T_0a2ef_row6_col5" class="data row6 col5" >0.1243</td>
#             </tr>
#             <tr>
#                         <th id="T_0a2ef_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_0a2ef_row7_col0" class="data row7 col0" >55.5395</td>
#                         <td id="T_0a2ef_row7_col1" class="data row7 col1" >5274.3608</td>
#                         <td id="T_0a2ef_row7_col2" class="data row7 col2" >72.6248</td>
#                         <td id="T_0a2ef_row7_col3" class="data row7 col3" >0.7262</td>
#                         <td id="T_0a2ef_row7_col4" class="data row7 col4" >0.8180</td>
#                         <td id="T_0a2ef_row7_col5" class="data row7 col5" >0.1279</td>
#             </tr>
#             <tr>
#                         <th id="T_0a2ef_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_0a2ef_row8_col0" class="data row8 col0" >64.0048</td>
#                         <td id="T_0a2ef_row8_col1" class="data row8 col1" >8289.2383</td>
#                         <td id="T_0a2ef_row8_col2" class="data row8 col2" >91.0453</td>
#                         <td id="T_0a2ef_row8_col3" class="data row8 col3" >0.6036</td>
#                         <td id="T_0a2ef_row8_col4" class="data row8 col4" >0.7922</td>
#                         <td id="T_0a2ef_row8_col5" class="data row8 col5" >0.1549</td>
#             </tr>
#             <tr>
#                         <th id="T_0a2ef_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_0a2ef_row9_col0" class="data row9 col0" >61.7286</td>
#                         <td id="T_0a2ef_row9_col1" class="data row9 col1" >8596.4502</td>
#                         <td id="T_0a2ef_row9_col2" class="data row9 col2" >92.7170</td>
#                         <td id="T_0a2ef_row9_col3" class="data row9 col3" >0.6737</td>
#                         <td id="T_0a2ef_row9_col4" class="data row9 col4" >1.5004</td>
#                         <td id="T_0a2ef_row9_col5" class="data row9 col5" >0.1160</td>
#             </tr>
#             <tr>
#                         <th id="T_0a2ef_level0_row10" class="row_heading level0 row10" >Mean</th>
#                         <td id="T_0a2ef_row10_col0" class="data row10 col0" >59.0859</td>
#                         <td id="T_0a2ef_row10_col1" class="data row10 col1" >7000.2099</td>
#                         <td id="T_0a2ef_row10_col2" class="data row10 col2" >83.2642</td>
#                         <td id="T_0a2ef_row10_col3" class="data row10 col3" >0.6170</td>
#                         <td id="T_0a2ef_row10_col4" class="data row10 col4" >0.8300</td>
#                         <td id="T_0a2ef_row10_col5" class="data row10 col5" >0.1302</td>
#             </tr>
#             <tr>
#                         <th id="T_0a2ef_level0_row11" class="row_heading level0 row11" >SD</th>
#                         <td id="T_0a2ef_ro
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-636d82296a65> in <module>
#       2                   'booster': ['gbtree', 'gblinear', 'dart']}
#       3 xgb_ = tune_model(create_model('xgboost', gpu_id=0), optimize='MAE', custom_grid=params)
# ----> 4 Audio(soundfile, autoplay=True)
#
# NameError: name 'Audio' is not defined

# %%
pred_holdouts = predict_model(blended_d)
final_model_d = finalize_model(blended_d)
final_model_d
# Out:
# <style  type="text/css" >
# </style><table id="T_883b7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_883b7_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_883b7_row0_col0" class="data row0 col0" >Voting Regressor</td>
#                         <td id="T_883b7_row0_col1" class="data row0 col1" >61.9571</td>
#                         <td id="T_883b7_row0_col2" class="data row0 col2" >8127.8475</td>
#                         <td id="T_883b7_row0_col3" class="data row0 col3" >90.1546</td>
#                         <td id="T_883b7_row0_col4" class="data row0 col4" >0.5818</td>
#                         <td id="T_883b7_row0_col5" class="data row0 col5" >0.9736</td>
#                         <td id="T_883b7_row0_col6" class="data row0 col6" >0.1405</td>
#             </tr>
#     </tbody></table>
# VotingRegressor(estimators=[('rf',
#                              RandomForestRegressor(bootstrap=True,
#                                                    ccp_alpha=0.0,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
#                                                    min_samples_split=2,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=100, n_jobs=-1,
#                                                    oob_score=False,
#                                                    random_state=2, v...
#                                           learning_rate=0.300000012,
#                                           max_delta_step=0, max_depth=6,
#                                           min_child_weight=1, missing=nan,
#                                           monotone_constraints='()',
#                                           n_estimators=100, n_jobs=-1,
#                                           num_parallel_tree=1,
#                                           objective='reg:squarederror',
#                                           random_state=2, reg_alpha=0,
#                                           reg_lambda=1, scale_pos_weight=1,
#                                           subsample=1, tree_method='auto',
#                                           validate_parameters=1,
#                                           verbosity=0))],
#                 n_jobs=-1, verbose=False, weights=None)

# %% [markdown]
# # 추론

# %% [markdown]
# ## Test 5일마다 split

# %%
submission_df = pd.read_csv('submission/sub_f2.csv')

# %%
submission_df
# Out:
#             일자          중식계         석식계
# 0   2021-01-27   904.510674  389.667138
# 1   2021-01-28   904.011825  443.825444
# 2   2021-01-29   594.587829  276.191645
# 3   2021-02-01  1174.937702  588.832850
# 4   2021-02-02  1033.847466  548.337170
# 5   2021-02-03   961.142505    0.000000
# 6   2021-02-04   981.898490    0.000000
# 7   2021-02-05   728.021027    0.000000
# 8   2021-02-08  1280.646079    0.000000
# 9   2021-02-09  1030.937603    0.000000
# 10  2021-02-10   734.362591    0.000000
# 11  2021-02-15  1290.188907    0.000000
# 12  2021-02-16  1147.482230    0.000000
# 13  2021-02-17   945.004599    0.000000
# 14  2021-02-18   920.027688    0.000000
# 15  2021-02-19   709.513264    0.000000
# 16  2021-02-22  1278.684550    0.000000
# 17  2021-02-23  1046.407114    0.000000
# 18  2021-02-24   888.963268    0.000000
# 19  2021-02-25   901.669396    0.000000
# 20  2021-02-26   623.447447    0.000000
# 21  2021-03-02  1106.721969    0.000000
# 22  2021-03-03  1011.454828    0.000000
# 23  2021-03-04  1000.310064    0.000000
# 24  2021-03-05   785.270024    0.000000
# 25  2021-03-08  1384.497629    0.000000
# 26  2021-03-09  1325.095419    0.000000
# 27  2021-03-10  1018.543442    0.000000
# 28  2021-03-11   991.484654    0.000000
# 29  2021-03-12   773.866627    0.000000
# 30  2021-03-15  1303.889758    0.000000
# 31  2021-03-16  1058.921943    0.000000
# 32  2021-03-17   988.604193    0.000000
# 33  2021-03-18   959.097512    0.000000
# 34  2021-03-19   753.148498    0.000000
# 35  2021-03-22  1291.608841    0.000000
# 36  2021-03-23  1050.452229    0.000000
# 37  2021-03-24   912.578045    0.000000
# 38  2021-03-25   927.747807    0.000000
# 39  2021-03-26   740.789846    0.000000
# 40  2021-03-29  1293.732974    0.000000
# 41  2021-03-30  1065.043421    0.000000
# 42  2021-03-31   972.664823    0.000000
# 43  2021-04-01   877.826858    0.000000
# 44  2021-04-02   686.066918    0.000000
# 45  2021-04-05  1217.029514    0.000000
# 46  2021-04-06  1012.143728    0.000000
# 47  2021-04-07   920.345440    0.000000
# 48  2021-04-08   871.401998    0.000000
# 49  2021-04-09   687.889099    0.000000

# %%
test.columns
# Out:
# Index(['일자', '요일', '본사정원수', '본사휴가자수', '본사출장자수', '본사시간외근무명령서승인건수',
#        '현본사소속재택근무자수', '조식메뉴', '중식메뉴', '석식메뉴', '년', '월', '일', '식사가능자', '공휴일전후'],
#       dtype='object')

# %%
res = []
X_test = test[['일자', '요일', '본사시간외근무명령서승인건수', '공휴일전후', '본사출장자수',
                 '식사가능자', '월', '일']]
for i in range(len(X_test)):
    if i%5 == 0:
        res.append(X_test[i:i+5])

# %%
res = res[1:]
len(res)
# Out:
# 9

# %%
res[0]
# Out:
#            일자  요일  본사시간외근무명령서승인건수  공휴일전후  본사출장자수   식사가능자  월  일
# 5  2021-02-03   2               5      0     199  2380.0  2  3
# 6  2021-02-04   1             476      0     211  2364.0  2  4
# 7  2021-02-05   0               0      0     252  2247.0  2  5
# 8  2021-02-08   3             690      0     174  2333.0  2  8
# 9  2021-02-09   4             542      0     183  2318.0  2  9

# %%
from datetime import timedelta
prev = train
for idx, part_test in enumerate(res):
    part_test = make_dow_avg(part_test, prev)
    part_test = make_month_avg(part_test, prev)
    
    #pred 생성
    #pred_ln = predict_model(final_model_l, part_test.drop(['일자', '월'], axis=1))
    pred_dn = predict_model(final_model_d, part_test.drop(['일자'], axis=1))
    
    #submission 업데이트
    #submission_df['중식계'][5*(idx+1):5*(idx+1)+5] = pred_ln['Label']
    submission_df['석식계'][5*(idx+1):5*(idx+1)+5] = pred_dn['Label']

# %%
submission_df
# Out:
#             일자          중식계         석식계
# 0   2021-01-27   904.510674  389.667138
# 1   2021-01-28   904.011825  443.825444
# 2   2021-01-29   594.587829  276.191645
# 3   2021-02-01  1174.937702  588.832850
# 4   2021-02-02  1033.847466  548.337170
# 5   2021-02-03   961.142505  513.462262
# 6   2021-02-04   981.898490  559.514774
# 7   2021-02-05   728.021027  387.973353
# 8   2021-02-08  1280.646079  694.018465
# 9   2021-02-09  1030.937603  583.745168
# 10  2021-02-10   734.362591  205.929998
# 11  2021-02-15  1290.188907  738.556008
# 12  2021-02-16  1147.482230  723.330601
# 13  2021-02-17   945.004599  417.728277
# 14  2021-02-18   920.027688  589.738969
# 15  2021-02-19   709.513264  386.220890
# 16  2021-02-22  1278.684550  723.319124
# 17  2021-02-23  1046.407114  674.800479
# 18  2021-02-24   888.963268  431.231421
# 19  2021-02-25   901.669396  583.474030
# 20  2021-02-26   623.447447  295.744740
# 21  2021-03-02  1106.721969  663.641650
# 22  2021-03-03  1011.454828  538.523363
# 23  2021-03-04  1000.310064  626.551004
# 24  2021-03-05   785.270024  409.498698
# 25  2021-03-08  1384.497629  716.747643
# 26  2021-03-09  1325.095419  701.479399
# 27  2021-03-10  1018.543442  472.391895
# 28  2021-03-11   991.484654  615.941591
# 29  2021-03-12   773.866627  402.178908
# 30  2021-03-15  1303.889758  715.312607
# 31  2021-03-16  1058.921943  653.909531
# 32  2021-03-17   988.604193  467.865173
# 33  2021-03-18   959.097512  552.519866
# 34  2021-03-19   753.148498  356.530336
# 35  2021-03-22  1291.608841  667.345601
# 36  2021-03-23  1050.452229  651.837340
# 37  2021-03-24   912.578045  367.868231
# 38  2021-03-25   927.747807  531.288328
# 39  2021-03-26   740.789846  316.881189
# 40  2021-03-29  1293.732974  678.392335
# 41  2021-03-30  1065.043421  686.041961
# 42  2021-03-31   972.664823  424.690808
# 43  2021-04-01   877.826858  518.080940
# 44  2021-04-02   686.066918  384.930451
# 45  2021-04-05  1217.029514  622.656332
# 46  2021-04-06  1012.143728  623.264500
# 47  2021-04-07   920.345440  494.012067
# 48  2021-04-08   871.401998  515.737029
# 49  2021-04-09   687.889099  389.837128

# %%
submission_df.to_csv('submission/sub_f_inal.csv', index=False)

# %%
train['전주중식계'] = 0
train['전주석식계'] = 0
idx = pd.DatetimeIndex(train['일자']) + timedelta(weeks=-1)
for i in range(len(train)):
    try:
        train['전주중식계'][i] = train[train['일자'] == str(idx[i])[:10]]['중식계']
        train['전주석식계'][i] = train[train['일자'] == str(idx[i])[:10]]['석식계']
    except:
        train['전주중식계'][i] = train.iloc[i,:]['중식계']
        train['전주석식계'][i] = train.iloc[i,:]['석식계']

train[['중식계', '전주중식계', '석식계', '전주석식계', '일자']].head(10)
